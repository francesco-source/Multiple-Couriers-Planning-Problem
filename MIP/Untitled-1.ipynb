# %%
from pulp import *
import numpy as np
from mpi_utils import *

# %%
class Mcpp_var:
     def __init__(self, m, n, l, s, D):
        self.m = m
        self.n = n
        self.l = l
        self.s = s
        self.D = D


def load_instances(num: int):
  if num < 10:
    num = "0"+str(num)
  else:
    num = str(num)
  
  file = open(f"../input/inst{num}.dat", 'r')
  
  m = int(file.readline())
  n = int(file.readline())
  l = [int(x) for x in file.readline().split(" ") if x!= ""]
  s = [int(x) for x in file.readline().split(" ") if x!= ""]
  D = []
  for i in range(n+1):
      D.append([int(x) for x in file.readline().split(" ") if x!= "\n" if x!= ""])
  
  return Mcpp_var(m, n, l, s, D)

# %%
mcpp = load_instances(1)

# %%
def And(model, a, b, name):
        """
        And(a,b)
        :param a: first parameter of And condition
        :param b: second parameter of And condition
        :param name: name of the And
        :return: 1 if a and b is true, false otherwise
        """
        delta = LpVariable(cat=LpBinary, name=name)
        model += delta <= a
        model += delta >= a + b - 1
        model += delta >= 0
        model += delta <= b
        return delta
def linear_prod(model, binary_var, countinuos_var, ub, name):
        """
        res = binary_var * countinuos_var
        :param binary_var: binary variable
        :param countinuos_var: countinuos variable
        :param ub: upper bound of the countinuos variable
        :param name: name of the product
        :return: the result of the product
        """
        res = LpVariable(cat=LpInteger, name=name)
        model += ub * binary_var >= res
        model += countinuos_var >= res
        model += countinuos_var - (1 - binary_var) * ub <= res
        model += res >= 0
        return res

# %%
# matrix m*n*n+1 where we have couriers, order and packages
X  = [[[LpVariable(name = f'X_{i}_{k}_{j}', lowBound = 0, upBound = 1, cat = LpBinary) 
        for j in range(mcpp.n+1)] for k in range(mcpp.n)] for i in range(mcpp.m)]

#distance made by each courier
dist_courier = [LpVariable(name = f'dist_cour{i}', cat = LpInteger) for i in range(mcpp.m)]

# partial distance made by each courier
dist_par  = [[LpVariable(name = f'dist{i}_{j}', cat = LpInteger) for j in range(mcpp.n + 1 )] for i in range(mcpp.m)] 

maximum = LpVariable(name=f'maximum', lowBound = 0, upBound = 10000, cat = LpInteger)

model = LpProblem(name=f'mcpp1', sense=LpMinimize)

#1. One hot encoding 
for i in range(mcpp.m):
    for k in range(mcpp.n):
        model += lpSum(X[i][k]) == 1

#2. Each element only once in the cube
for j in range(1,mcpp.n + 1):
    model += lpSum([[X[i][k][j] for k in range(mcpp.n)] for i in range(mcpp.m)]) == 1

#3. Load size constraint ( migliora con LpAffineSumExpression)
for i in range(mcpp.m):
    model += lpSum([mcpp.s[j]*X[i][k][j+1] for j in range(mcpp.n) for k in range(mcpp.n)]) <= mcpp.l[i]
 
#4. Every courier must start.
model += lpSum(X[i][0][0] for i in range(mcpp.m)) == 0

#5. Constraint that if I see a 0, all the following element for a courier must be 0.
for i in range(mcpp.m):
    for k in range(mcpp.n - 1):  
      model += X[i][k][0] - X[i][k+1][0] <= 0
    
for i in range(mcpp.m):
    # from deposit to first package location
    model += dist_par[i][0] == lpSum([X[i][0][j] * mcpp.D[mcpp.n][j - 1] for j in range(1,mcpp.n)])
    for k in range(1,mcpp.n):
        for j in range(1,mcpp.n + 1):
            for j2 in range(1,mcpp.n + 1):
                if(j != j2):
                 model += dist_par[i][k] == LpAffineExpression([(And(model, X[i][k - 1][j], X[i][k][j2],f'and_{i}_{k}_{j}_{j2}'), mcpp.D[j - 1][j2 - 1])])
    #from last package location to deposit
    model += dist_par[i][mcpp.n] == lpSum(X[i][mcpp.n - 1][j] * mcpp.D[j-1][mcpp.n] for j in range(1,mcpp.n))

for i in range(mcpp.m):
    model += dist_courier[i] == lpSum(dist_par[i])

#7. Goal function. We want to minimize the max distance.
for i in range(mcpp.m):
    model += maximum >= lpSum(dist_par[i]) 
model += maximum
   
model.solve()
# Out:
# -1

# %%
for var in model.variables():
    print(f"{var.name}: Value = {var.varValue}")
# Out:
# X_0_0_0: Value = 0.0
# X_0_0_1: Value = 0.5
# X_0_0_2: Value = 0.0
# X_0_0_3: Value = 0.0
# X_0_0_4: Value = 0.0
# X_0_0_5: Value = 0.0
# X_0_0_6: Value = 0.5
# X_0_1_0: Value = 0.0
# X_0_1_1: Value = 0.0
# X_0_1_2: Value = 0.0
# X_0_1_3: Value = 0.5
# X_0_1_4: Value = 0.5
# X_0_1_5: Value = 0.0
# X_0_1_6: Value = 0.0
# X_0_2_0: Value = 0.5
# X_0_2_1: Value = 0.0
# X_0_2_2: Value = 0.0
# X_0_2_3: Value = 0.5
# X_0_2_4: Value = 0.0
# X_0_2_5: Value = 0.0
# X_0_2_6: Value = 0.0
# X_0_3_0: Value = 0.5
# X_0_3_1: Value = 0.0
# X_0_3_2: Value = 0.0
# X_0_3_3: Value = 0.0
# X_0_3_4: Value = 0.0
# X_0_3_5: Value = 0.5
# X_0_3_6: Value = 0.0
# X_0_4_0: Value = 1.0
# X_0_4_1: Value = 0.0
# X_0_4_2: Value = 0.0
# X_0_4_3: Value = 0.0
# X_0_4_4: Value = 0.0
# X_0_4_5: Value = 0.0
# X_0_4_6: Value = 0.0
# X_0_5_0: Value = 1.0
# X_0_5_1: Value = 0.0
# X_0_5_2: Value = 0.0
# X_0_5_3: Value = 0.0
# X_0_5_4: Value = 0.0
# X_0_5_5: Value = 0.0
# X_0_5_6: Value = 0.0
# X_1_0_0: Value = 0.0
# X_1_0_1: Value = 0.5
# X_1_0_2: Value = 0.0
# X_1_0_3: Value = 0.0
# X_1_0_4: Value = 0.0
# X_1_0_5: Value = 0.0
# X_1_0_6: Value = 0.5
# X_1_1_0: Value = 0.33333333
# X_1_1_1: Value = 0.0
# X_1_1_2: Value = 0.41666667
# X_1_1_3: Value = 0.0
# X_1_1_4: Value = 0.25
# X_1_1_5: Value = 0.0
# X_1_1_6: Value = 0.0
# X_1_2_0: Value = 0.33333333
# X_1_2_1: Value = 0.0
# X_1_2_2: Value = 0.58333333
# X_1_2_3: Value = 0.0
# X_1_2_4: Value = 0.0
# X_1_2_5: Value = 0.083333333
# X_1_2_6: Value = 0.0
# X_1_3_0: Value = 0.33333333
# X_1_3_1: Value = 0.0
# X_1_3_2: Value = 0.0
# X_1_3_3: Value = 0.0
# X_1_3_4: Value = 0.25
# X_1_3_5: Value = 0.41666667
# X_1_3_6: Value = 0.0
# X_1_4_0: Value = 1.0
# X_1_4_1: Value = 0.0
# X_1_4_2: Value = 0.0
# X_1_4_3: Value = 0.0
# X_1_4_4: Value = 0.0
# X_1_4_5: Value = 0.0
# X_1_4_6: Value = 0.0
# X_1_5_0: Value = 1.0
# X_1_5_1: Value = 0.0
# X_1_5_2: Value = 0.0
# X_1_5_3: Value = 0.0
# X_1_5_4: Value = 0.0
# X_1_5_5: Value = 0.0
# X_1_5_6: Value = 0.0
# and_0_1_1_2: Value = 0.0
# and_0_1_1_3: Value = 0.0
# and_0_1_1_4: Value = 0.0
# and_0_1_1_5: Value = 0.0
# and_0_1_1_6: Value = 0.0
# and_0_1_2_1: Value = 0.0
# and_0_1_2_3: Value = 0.0
# and_0_1_2_4: Value = 0.0
# and_0_1_2_5: Value = 0.0
# and_0_1_2_6: Value = 0.0
# and_0_1_3_1: Value = 0.0
# and_0_1_3_2: Value = 0.0
# and_0_1_3_4: Value = 0.0
# and_0_1_3_5: Value = 0.0
# and_0_1_3_6: Value = 0.0
# and_0_1_4_1: Value = 0.0
# and_0_1_4_2: Value = 0.0
# and_0_1_4_3: Value = 0.0
# and_0_1_4_5: Value = 0.0
# and_0_1_4_6: Value = 0.0
# and_0_1_5_1: Value = 0.0
# and_0_1_5_2: Value = 0.0
# and_0_1_5_3: Value = 0.0
# and_0_1_5_4: Value = 0.0
# and_0_1_5_6: Value = 0.0
# and_0_1_6_1: Value = 0.0
# and_0_1_6_2: Value = 0.0
# and_0_1_6_3: Value = 0.0
# and_0_1_6_4: Value = 0.0
# and_0_1_6_5: Value = 0.0
# and_0_2_1_2: Value = 0.0
# and_0_2_1_3: Value = 0.0
# and_0_2_1_4: Value = 0.0
# and_0_2_1_5: Value = 0.0
# and_0_2_1_6: Value = 0.0
# and_0_2_2_1: Value = 0.0
# and_0_2_2_3: Value = 0.0
# and_0_2_2_4: Value = 0.0
# and_0_2_2_5: Value = 0.0
# and_0_2_2_6: Value = 0.0
# and_0_2_3_1: Value = 0.0
# and_0_2_3_2: Value = 0.0
# and_0_2_3_4: Value = 0.0
# and_0_2_3_5: Value = 0.0
# and_0_2_3_6: Value = 0.0
# and_0_2_4_1: Value = 0.0
# and_0_2_4_2: Value = 0.0
# and_0_2_4_3: Value = 0.0
# and_0_2_4_5: Value = 0.0
# and_0_2_4_6: Value = 0.0
# and_0_2_5_1: Value = 0.0
# and_0_2_5_2: Value = 0.0
# and_0_2_5_3: Value = 0.0
# and_0_2_5_4: Value = 0.0
# and_0_2_5_6: Value = 0.0
# and_0_2_6_1: Value = 0.0
# and_0_2_6_2: Value = 0.0
# and_0_2_6_3: Value = 0.0
# and_0_2_6_4: Value = 0.0
# and_0_2_6_5: Value = 0.0
# and_0_3_1_2: Value = 0.0
# and_0_3_1_3: Value = 0.0
# and_0_3_1_4: Value = 0.0
# and_0_3_1_5: Value = 0.0
# and_0_3_1_6: Value = 0.0
# and_0_3_2_1: Value = 0.0
# and_0_3_2_3: Value = 0.0
# and_0_3_2_4: Value = 0.0
# and_0_3_2_5: Value = 0.0
# and_0_3_2_6: Value = 0.0
# and_0_3_3_1: Value = 0.0
# and_0_3_3_2: Value = 0.0
# and_0_3_3_4: Value = 0.0
# and_0_3_3_5: Value = 0.0
# and_0_3_3_6: Value = 0.0
# and_0_3_4_1: Value = 0.0
# and_0_3_4_2: Value = 0.0
# and_0_3_4_3: Value = 0.0
# and_0_3_4_5: Value = 0.0
# and_0_3_4_6: Value = 0.0
# and_0_3_5_1: Value = 0.0
# and_0_3_5_2: Value = 0.0
# and_0_3_5_3: Value = 0.0
# and_0_3_5_4: Value = 0.0
# and_0_3_5_6: Value = 0.0
# and_0_3_6_1: Value = 0.0
# and_0_3_6_2: Value = 0.0
# and_0_3_6_3: Value = 0.0
# and_0_3_6_4: Value = 0.0
# and_0_3_6_5: Value = 0.0
# and_0_4_1_2: Value = 0.0
# and_0_4_1_3: Value = 0.0
# and_0_4_1_4: Value = 0.0
# and_0_4_1_5: Value = 0.0
# and_0_4_1_6: Value = 0.0
# and_0_4_2_1: Value = 0.0
# and_0_4_2_3: Value = 0.0
# and_0_4_2_4: Value = 0.0
# and_0_4_2_5: Value = 0.0
# and_0_4_2_6: Value = 0.0
# and_0_4_3_1: Value = 0.0
# and_0_4_3_2: Value = 0.0
# and_0_4_3_4: Value = 0.0
# and_0_4_3_5: Value = 0.0
# and_0_4_3_6: Value = 0.0
# and_0_4_4_1: Value = 0.0
# and_0_4_4_2: Value = 0.0
# and_0_4_4_3: Value = 0.0
# and_0_4_4_5: Value = 0.0
# and_0_4_4_6: Value = 0.0
# and_0_4_5_1: Value = 0.0
# and_0_4_5_2: Value = 0.0
# and_0_4_5_3: Value = 0.0
# and_0_4_5_4: Value = 0.0
# and_0_4_5_6: Value = 0.0
# and_0_4_6_1: Value = 0.0
# and_0_4_6_2: Value = 0.0
# and_0_4_6_3: Value = 0.0
# and_0_4_6_4: Value = 0.0
# and_0_4_6_5: Value = 0.0
# and_0_5_1_2: Value = 0.0
# and_0_5_1_3: Value = 0.0
# and_0_5_1_4: Value = 0.0
# and_0_5_1_5: Value = 0.0
# and_0_5_1_6: Value = 0.0
# and_0_5_2_1: Value = 0.0
# and_0_5_2_3: Value = 0.0
# and_0_5_2_4: Value = 0.0
# and_0_5_2_5: Value = 0.0
# and_0_5_2_6: Value = 0.0
# and_0_5_3_1: Value = 0.0
# and_0_5_3_2: Value = 0.0
# and_0_5_3_4: Value = 0.0
# and_0_5_3_5: Value = 0.0
# and_0_5_3_6: Value = 0.0
# and_0_5_4_1: Value = 0.0
# and_0_5_4_2: Value = 0.0
# and_0_5_4_3: Value = 0.0
# and_0_5_4_5: Value = 0.0
# and_0_5_4_6: Value = 0.0
# and_0_5_5_1: Value = 0.0
# and_0_5_5_2: Value = 0.0
# and_0_5_5_3: Value = 0.0
# and_0_5_5_4: Value = 0.0
# and_0_5_5_6: Value = 0.0
# and_0_5_6_1: Value = 0.0
# and_0_5_6_2: Value = 0.0
# and_0_5_6_3: Value = 0.0
# and_0_5_6_4: Value = 0.0
# and_0_5_6_5: Value = 0.0
# and_1_1_1_2: Value = 0.0
# and_1_1_1_3: Value = 0.0
# and_1_1_1_4: Value = 0.0
# and_1_1_1_5: Value = 0.0
# and_1_1_1_6: Value = 0.0
# and_1_1_2_1: Value = 0.0
# and_1_1_2_3: Value = 0.0
# and_1_1_2_4: Value = 0.0
# and_1_1_2_5: Value = 0.0
# and_1_1_2_6: Value = 0.0
# and_1_1_3_1: Value = 0.0
# and_1_1_3_2: Value = 0.0
# and_1_1_3_4: Value = 0.0
# and_1_1_3_5: Value = 0.0
# and_1_1_3_6: Value = 0.0
# and_1_1_4_1: Value = 0.0
# and_1_1_4_2: Value = 0.0
# and_1_1_4_3: Value = 0.0
# and_1_1_4_5: Value = 0.0
# and_1_1_4_6: Value = 0.0
# and_1_1_5_1: Value = 0.0
# and_1_1_5_2: Value = 0.0
# and_1_1_5_3: Value = 0.0
# and_1_1_5_4: Value = 0.0
# and_1_1_5_6: Value = 0.0
# and_1_1_6_1: Value = 0.0
# and_1_1_6_2: Value = 0.0
# and_1_1_6_3: Value = 0.0
# and_1_1_6_4: Value = 0.0
# and_1_1_6_5: Value = 0.0
# and_1_2_1_2: Value = 0.0
# and_1_2_1_3: Value = 0.0
# and_1_2_1_4: Value = 0.0
# and_1_2_1_5: Value = 0.0
# and_1_2_1_6: Value = 0.0
# and_1_2_2_1: Value = 0.0
# and_1_2_2_3: Value = 0.0
# and_1_2_2_4: Value = 0.0
# and_1_2_2_5: Value = 0.0
# and_1_2_2_6: Value = 0.0
# and_1_2_3_1: Value = 0.0
# and_1_2_3_2: Value = 0.0
# and_1_2_3_4: Value = 0.0
# and_1_2_3_5: Value = 0.0
# and_1_2_3_6: Value = 0.0
# and_1_2_4_1: Value = 0.0
# and_1_2_4_2: Value = 0.0
# and_1_2_4_3: Value = 0.0
# and_1_2_4_5: Value = 0.0
# and_1_2_4_6: Value = 0.0
# and_1_2_5_1: Value = 0.0
# and_1_2_5_2: Value = 0.0
# and_1_2_5_3: Value = 0.0
# and_1_2_5_4: Value = 0.0
# and_1_2_5_6: Value = 0.0
# and_1_2_6_1: Value = 0.0
# and_1_2_6_2: Value = 0.0
# and_1_2_6_3: Value = 0.0
# and_1_2_6_4: Value = 0.0
# and_1_2_6_5: Value = 0.0
# and_1_3_1_2: Value = 0.0
# and_1_3_1_3: Value = 0.0
# and_1_3_1_4: Value = 0.0
# and_1_3_1_5: Value = 0.0
# and_1_3_1_6: Value = 0.0
# and_1_3_2_1: Value = 0.0
# and_1_3_2_3: Value = 0.0
# and_1_3_2_4: Value = 0.0
# and_1_3_2_5: Value = 0.0
# and_1_3_2_6: Value = 0.0
# and_1_3_3_1: Value = 0.0
# and_1_3_3_2: Value = 0.0
# and_1_3_3_4: Value = 0.0
# and_1_3_3_5: Value = 0.0
# and_1_3_3_6: Value = 0.0
# and_1_3_4_1: Value = 0.0
# and_1_3_4_2: Value = 0.0
# and_1_3_4_3: Value = 0.0
# and_1_3_4_5: Value = 0.0
# and_1_3_4_6: Value = 0.0
# and_1_3_5_1: Value = 0.0
# and_1_3_5_2: Value = 0.0
# and_1_3_5_3: Value = 0.0
# and_1_3_5_4: Value = 0.0
# and_1_3_5_6: Value = 0.0
# and_1_3_6_1: Value = 0.0
# and_1_3_6_2: Value = 0.0
# and_1_3_6_3: Value = 0.0
# and_1_3_6_4: Value = 0.0
# and_1_3_6_5: Value = 0.0
# and_1_4_1_2: Value = 0.0
# and_1_4_1_3: Value = 0.0
# and_1_4_1_4: Value = 0.0
# and_1_4_1_5: Value = 0.0
# and_1_4_1_6: Value = 0.0
# and_1_4_2_1: Value = 0.0
# and_1_4_2_3: Value = 0.0
# and_1_4_2_4: Value = 0.0
# and_1_4_2_5: Value = 0.0
# and_1_4_2_6: Value = 0.0
# and_1_4_3_1: Value = 0.0
# and_1_4_3_2: Value = 0.0
# and_1_4_3_4: Value = 0.0
# and_1_4_3_5: Value = 0.0
# and_1_4_3_6: Value = 0.0
# and_1_4_4_1: Value = 0.0
# and_1_4_4_2: Value = 0.0
# and_1_4_4_3: Value = 0.0
# and_1_4_4_5: Value = 0.0
# and_1_4_4_6: Value = 0.0
# and_1_4_5_1: Value = 0.0
# and_1_4_5_2: Value = 0.0
# and_1_4_5_3: Value = 0.0
# and_1_4_5_4: Value = 0.0
# and_1_4_5_6: Value = 0.0
# and_1_4_6_1: Value = 0.0
# and_1_4_6_2: Value = 0.0
# and_1_4_6_3: Value = 0.0
# and_1_4_6_4: Value = 0.0
# and_1_4_6_5: Value = 0.0
# and_1_5_1_2: Value = 0.0
# and_1_5_1_3: Value = 0.0
# and_1_5_1_4: Value = 0.0
# and_1_5_1_5: Value = 0.0
# and_1_5_1_6: Value = 0.0
# and_1_5_2_1: Value = 0.0
# and_1_5_2_3: Value = 0.0
# and_1_5_2_4: Value = 0.0
# and_1_5_2_5: Value = 0.0
# and_1_5_2_6: Value = 0.0
# and_1_5_3_1: Value = 0.0
# and_1_5_3_2: Value = 0.0
# and_1_5_3_4: Value = 0.0
# and_1_5_3_5: Value = 0.0
# and_1_5_3_6: Value = 0.0
# and_1_5_4_1: Value = 0.0
# and_1_5_4_2: Value = 0.0
# and_1_5_4_3: Value = 0.0
# and_1_5_4_5: Value = 0.0
# and_1_5_4_6: Value = 0.0
# and_1_5_5_1: Value = 0.0
# and_1_5_5_2: Value = 0.0
# and_1_5_5_3: Value = 0.0
# and_1_5_5_4: Value = 0.0
# and_1_5_5_6: Value = 0.0
# and_1_5_6_1: Value = 0.0
# and_1_5_6_2: Value = 0.0
# and_1_5_6_3: Value = 0.0
# and_1_5_6_4: Value = 0.0
# and_1_5_6_5: Value = 0.0
# dist0_0: Value = 1.0
# dist0_1: Value = 0.0
# dist0_2: Value = 0.0
# dist0_3: Value = 0.0
# dist0_4: Value = 0.0
# dist0_5: Value = 0.0
# dist0_6: Value = 0.0
# dist1_0: Value = 1.0
# dist1_1: Value = 0.0
# dist1_2: Value = 0.0
# dist1_3: Value = 0.0
# dist1_4: Value = 0.0
# dist1_5: Value = 0.0
# dist1_6: Value = 0.0
# dist_cour0: Value = 1.0
# dist_cour1: Value = 1.0
# maximum: Value = 1.0
